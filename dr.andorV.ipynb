# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\anton\Downloads\crap_dupliacates.csv")
df
# Out:
#        Unnamed: 0  Client ID  Client tenure year  Client tenure month  \
# 0               0     836976                 6.0                 73.0
# 1               1    2304905                 7.0                 94.0
# 2               2    1439522                 5.0                 64.0
# 3               3    1562045                16.0                198.0
# 4               4    5126305                12.0                145.0
# ...           ...        ...                 ...                  ...
# 50482       50482    1780858                21.0                262.0
# 50483       50483    6967120                21.0                260.0
# 50484       50484    5826160                20.0                249.0
# 50485       50485    8739285                19.0                229.0
# 50486       50486    7468138                18.0                222.0
#
#        Client age Gender  Number of accounts     Balance  \
# 0            60.0      U                 2.0    45105.30
# ...

# %%
df['visit_duration'] = pd.to_timedelta(df['visit_duration'])

df['visit_duration'] = df['visit_duration'].dt.total_seconds()

df = df[df["visit_duration"] != 0]

# %%
condition_1 = df["Variation"] == "Test"
condition_2 = df["Variation"] == "Control"
test_= df[condition_1]["visit_duration"]
control_ = df[condition_2]["visit_duration"]

#h0: avg test = avg control
#h1: avg test != avg control

stats.ttest_ind(test_, control_)

#p>alpha, so we reject null hypothesis
# Out:
# TtestResult(statistic=3.848951645501032, pvalue=0.00011879304539917155, df=43717.0)

# %%
df.sort_values("Client ID")
# Out:
#        Unnamed: 0  Client ID  Client tenure year  Client tenure month  \
# 40117       40117        555                 3.0                 46.0
# 1532         1532        647                12.0                151.0
# 13138       13138        934                 9.0                109.0
# 47507       47507       1028                12.0                145.0
# 44724       44724       1186                 8.0                 99.0
# ...           ...        ...                 ...                  ...
# 17626       17626    9999150                 5.0                 66.0
# 30530       30530    9999400                 7.0                 86.0
# 3228         3228    9999626                 9.0                113.0
# 48744       48744    9999729                10.0                124.0
# 8010         8010    9999832                23.0                281.0
#
#        Client age Gender  Number of accounts    Balance  \
# 40117        30.0      U                 2.0   25454.66
# ...

# %%
df["visit_duration"] = round(df["visit_duration"] / 60).astype(int)
df
# Out:
# C:\Users\anton\AppData\Local\Temp\ipykernel_20372\931187138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["visit_duration"] = round(df["visit_duration"] / 60).astype(int)
#        Unnamed: 0  Client ID  Client tenure year  Client tenure month  \
# 0               0     836976                 6.0                 73.0
# 1               1    2304905                 7.0                 94.0
# 2               2    1439522                 5.0                 64.0
# 5               5    3727881                 5.0                 71.0
# 6               6     272934                 5.0                 66.0
# ...           ...        ...                 ...                  ...
# ...

# %%
df.to_csv(r"C:\Users\anton\Downloads\drandorTTT.csv")
